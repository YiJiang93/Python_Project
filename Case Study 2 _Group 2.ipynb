# %% [markdown]
# #Case Study 2 : MoneyBall: data science in sports games
# ** Due Date: October 7, before the class**
#
#
# <a href="https://www.youtube.com/watch?v=AiAHlZVgXjk"> <img src="http://ia.media-imdb.com/images/M/MV5BMjAxOTU3Mzc1M15BMl5BanBnXkFtZTcwMzk1ODUzNg@@._V1_SX640_SY720_.jpg" width="300px"> </a>
# *------------

# %% [markdown]
# # Background & Motivation

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/a/ae/MONEYBALLchart.png" width="800">
#
# The central premise of ''Moneyball'' is that the collected wisdom of baseball insiders (including players, managers, coaches, scouts, and the front office) over the past century is subjective and often flawed. Statistics such as stolen bases, run batted in|runs batted in, and batting average, typically used to gauge players, are relics of a 19th century view of the game and the statistics that were available at the time. The book argues that the Oakland A's' front office took advantage of more analytical gauges of player performance to field a team that could compete successfully against richer competitors in Major League Baseball (MLB).
#
# Rigorous statistical analysis had demonstrated that on-base percentage and slugging percentage are better indicators of offensive success, and the A's became convinced that these qualities were cheaper to obtain on the open market than more historically valued qualities such as speed and contact. These observations often flew in the face of conventional baseball wisdom and the beliefs of many baseball scouts and executives.
#
# * By re-evaluating the strategies that produce wins on the field, the 2002 Oakland Athletics, with approximately \$41 million in salary, were competitive with larger market teams such as the New York Yankees, who spent over $125 million in payroll that same season. Because of the team's smaller revenues, Oakland is forced to find players undervalued by the market, and their system for finding value in undervalued players has proven itself thus far.
#
# Several themes Lewis explored in the book include: insiders vs. outsiders (established traditionalists vs. upstart proponents of sabermetrics), the democratization of information causing a flattening of hierarchies, and "the ruthless drive for efficiency that capitalism demands." The book also touches on Oakland's underlying economic need to stay ahead of the curve; as other teams begin mirroring Beane's strategies to evaluate offensive talent, diminishing the Athletics' advantage, Oakland begins looking for other undervalued baseball skills such as defensive capabilities.
#
# ''Moneyball'' also touches on the A's methods of prospect selection. Sabermetricians argue that a college baseball player's chance of MLB success is much higher than a traditional high school draft pick. Beane maintains that high draft picks spent on high school prospects, regardless of talent or physical potential as evaluated by traditional scouting, are riskier than if they were spent on more polished college players. Lewis cites A's minor leaguer Jeremy Bonderman, drafted out of high school in 2001 over Beane's objections, as but one example of precisely the type of draft pick Beane would avoid. Bonderman had all of the traditional "tools" that scouts look for, but thousands of such players have been signed by MLB organizations out of high school over the years and failed to develop. Lewis explores the A's approach to the 2002 MLB Draft, when the team had a nearly unprecedented run of early picks. The book documents Beane's often-tense discussions with his scouting staff (who  favored traditional subjective evaluation of potential rather than objective sabermetrics) in preparation for the draft to the actual draft, which defied all expectations and was considered at the time a wildly successful (if unorthodox) effort by Beane.
#
# * In addition, ''Moneyball'' traces the history of the sabermetric movement back to such people as Bill James (now a member of the Boston Red Sox front office) and Craig R. Wright. Lewis explores how James' seminal ''Baseball Abstract'', an annual publication that was published from the late 1970s through the late 1980s, influenced many of the young, up-and-coming baseball minds that are now joining the ranks of baseball management.
#
# ''Moneyball'' has made such an impact in professional baseball that the term itself has entered the lexicon of baseball. Teams which appear to value the concepts of sabermetrics are often said to be playing "''Moneyball''." Baseball traditionalists, in particular some scouts and media members, decry the sabermetric revolution and have disparaged ''Moneyball'' for emphasizing concepts of sabermetrics over more traditional methods of player evaluation. Nevertheless, the impact of ''Moneyball'' upon major league front offices is undeniable.
# *In its wake, teams such as the New York Mets, New York Yankees, San Diego Padres, St. Louis Cardinals, Boston Red Sox, Washington Nationals, Arizona Diamondbacks, Cleveland Indians, (http://www.baseballprospectus.com/article.php?articleid=6187 - Aim For The Head: Aim For the Front Office) and the Toronto Blue Jays  have hired full-time sabermetric data scientists.
# Since the book's publication and success, Lewis has discussed plans for a sequel to ''Moneyball'' called ''Underdogs'', revisiting the players and their relative success several years into their careers. When the New York Mets hired Sandy Alderson &ndash; Beane's predecessor and mentor with the A's &ndash; as their general manager after the 2010 season, and hired Beane's former associates Paul DePodesta  and J.P. Ricciardi to the front office, the team became known as the "Moneyball Mets".(http://nymag.com/news/sports/games/sandy-alderson-2011-4/  The Moneyball Mets) Michael Lewis has acknowledged that the book's success may have negatively affected the Athletics' fortunes as other teams have accepted the use of sabermetrics, reducing the edge that Oakland received from using sabermetric-based evaluations. (http://www.sfgate.com/cgi-bin/article.cgi?f=/c/a/2011/09/18/SP3J1L571K.DTL&ao=all Michael Lewis on A's 'Moneyball' legacy)
#
#
# -- Cited from https://en.wikibooks.org/wiki/Data_Science:_An_Introduction/The_Impact_of_Data_Science

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("WNlCBy07z08")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/WNlCBy07z08"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
YouTubeVideo("zjU7R-6ShdE")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/zjU7R-6ShdE"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
YouTubeVideo("nK1jtVhimPA")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/nK1jtVhimPA"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
YouTubeVideo("AxsNitIS9E8")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/AxsNitIS9E8"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# --------------
# **TEAM Members:** Please EDIT this cell and add the names of all the team members in your team
#
#     Xiang Huang
#
#     Harsh Vardhan
#
#     ZhongZheng Shu
#
#     Yi Jiang

# %% [markdown]
# **Desired outcome of the case study.**
# * In this case study we will look at the NBA Data from http://stats.nba.com.
#     * It contains data about players, game details and statistics.
# * The idea is to *analyze* the data set, make *conjectures*, support or refute those conjectures with *data*, and *tell a story* about the data!
#
# **Required Readings:**
# * http://savvastjortjoglou.com/nba-play-by-play-movements.html
# * http://savvastjortjoglou.com/nba-shot-sharts.html
#
# **Case study assumptions:**
# * You have access to a python installation
#
# **Required Python libraries:**
# * Pandas (pandas.pydata.org)
# * Matplotlib (matplotlib.org)
# * py-Goldsberry (https://github.com/bradleyfay/py-Goldsberry)
# * requests (http://www.python-requests.org/en/latest/)
# * seaborn (http://stanford.edu/~mwaskom/software/seaborn/)
# * nbastats (https://github.com/bradleyfay/NBAStats)
# * If you need help installing them then you can refer to Chapter 1 of Python for Data Analysis book
#
# ** NOTE **
# * Please don't forget to save the notebook frequently when working in IPython Notebook, otherwise the changes you made can be lost.
#
# *----------------------

# %% [markdown]
# # Problem 1: Collecting data about NBA players (5 points)

# %% [markdown]
# * use py-Goldsberry (https://github.com/bradleyfay/py-Goldsberry) tool to get a list of NBA players's information, such as names and player IDs
# * Load the player's information into a data frame in pandas package (pandas.pydata.org)
# * You could choose to download the list players of only one year or of all years.
# * Show/print the top 20 players in the list

# %%
import goldsberry
import pandas as pd

#-------------------------------
# Your code goes here.
# Add as many cells as you need
#-------------------------------

#get the current players for 2015 season
playersCurrent = pd.DataFrame(goldsberry.PlayerList(2015))

#print the top 20 players
playersCurrent.head(20)
# Out:
#    DISPLAY_LAST_COMMA_FIRST FROM_YEAR  PERSON_ID         PLAYERCODE  \
# 0               Acy, Quincy      2012     203112         quincy_acy
# 1             Adams, Jordan      2014     203919       jordan_adams
# 2             Adams, Steven      2013     203500       steven_adams
# 3              Adrien, Jeff      2010     202399        jeff_adrien
# 4            Afflalo, Arron      2007     201167      arron_afflalo
# 5            Ajinca, Alexis      2008     201582      alexis_ajinca
# 6           Aldemir, Furkan      2014     203128     furkan_aldemir
# 7             Aldrich, Cole      2010     202332       cole_aldrich
# 8        Aldridge, LaMarcus      2006     200746  lamarcus_aldridge
# 9          Alexander, Cliff      2015    1626146    cliff_alexander
# 10             Allen, Lavoy      2011     202730        lavoy_allen
# 11              Allen, Tony      2004       2754         tony_allen
# 12         Aminu, Al-Farouq      2010     202329    al-farouq_aminu
# 13            Amundson, Lou      2006     200811       lou_amundson
# 14          Andersen, Chris      2001       2365     chris_andersen
# 15           Anderson, Alan      2005     101187      alan_anderson
# 16           Anderson, Jake      2015     202815      jake_anderson
# 17          Anderson, James      2010     202341     james_anderson
# 18         Anderson, Justin      2015    1626147    justin_anderson
# 19           Anderson, Kyle      2014     203937      kyle_anderson
#
#     ROSTERSTATUS TEAM_ABBREVIATION      TEAM_CITY  TEAM_CODE     TEAM_ID  \
# 0              1               SAC     Sacramento      kings  1610612758
# 1              1               MEM        Memphis  grizzlies  1610612763
# 2              1               OKC  Oklahoma City    thunder  1610612760
# 3              1               NOP    New Orleans   pelicans  1610612740
# 4              1               NYK       New York     knicks  1610612752
# 5              1               NOP    New Orleans   pelicans  1610612740
# 6              1               PHI   Philadelphia     sixers  1610612755
# 7              1               LAC    Los Angeles   clippers  1610612746
# 8              1               SAS    San Antonio      spurs  1610612759
# 9              1               POR       Portland    blazers  1610612757
# 10             1               IND        Indiana     pacers  1610612754
# 11             1               MEM        Memphis  grizzlies  1610612763
# 12             1               POR       Portland    blazers  1610612757
# 13             1               NYK       New York     knicks  1610612752
# 14             1               MIA          Miami       heat  1610612748
# 15             1               WAS     Washington    wizards  1610612764
# 16             1               CHI        Chicago      bulls  1610612741
# 17             1               SAC     Sacramento      kings  1610612758
# 18             1               DAL         Dallas  mavericks  1610612742
# 19             1               SAS    San Antonio      spurs  1610612759
#
#         TEAM_NAME TO_YEAR
# 0           Kings    2015
# 1       Grizzlies    2015
# 2         Thunder    2015
# 3        Pelicans    2015
# 4          Knicks    2015
# 5        Pelicans    2015
# 6           76ers    2015
# 7        Clippers    2015
# 8           Spurs    2015
# 9   Trail Blazers    2015
# 10         Pacers    2015
# 11      Grizzlies    2015
# 12  Trail Blazers    2015
# 13         Knicks    2015
# 14           Heat    2015
# 15        Wizards    2015
# 16          Bulls    2015
# 17          Kings    2015
# 18      Mavericks    2015
# 19          Spurs    2015

# %% [markdown]
# # Problem 2: Shot Chart of the Player (15 points)

# %% [markdown]
# * Select a player that you are interested in, for example, "Yao Ming", or "Carmelo Anthony". You can get the player's ID from the data in Problem 1.
# * Edit this cell and get the photo of the player from NBA stats website based upon the player id.
#
# For example:<br>
#
# <img src="http://stats.nba.com/media/players/230x185/2544.png" width="200px">
#
# * Use NBA Shot API of nbastats library to collect the shot data of the player.
# * show the top 20 rows of the list.

# %%
# set DISPLAY_LAST_COMMA_FIRST as index so that we can search players by their name, "last name, first name"
playersCurrent.index = [playersCurrent.DISPLAY_LAST_COMMA_FIRST.values]

# find LeBron James' PERSON_ID (PlayerID)
playersCurrent.ix['James, LeBron']['PERSON_ID']
# Out:
# 2544

# %%
import nbastats.nbastats as nbastats

#-------------------------------
# Your code goes here.
# Add as many cells as you need
#-------------------------------

# create a ShotChart for LeBron James
Lebron = nbastats.ShotChart('2544')
Lebron.shotchart().head(20)
# Out:
#             GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID   PLAYER_NAME     TEAM_ID   TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING   EVENT_TYPE                     ACTION_TYPE       SHOT_TYPE    SHOT_ZONE_BASIC         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG
# 0   Shot Chart Detail  0021300002             27       2544  LeBron James  1610612748  Miami Heat       1                  8                 46  Missed Shot              Fadeaway Jump Shot  2PT Field Goal          Mid-Range          Right Side(R)         8-16 ft.             14     97    107                    1               0
# 1   Shot Chart Detail  0021300002             46       2544  LeBron James  1610612748  Miami Heat       1                  7                  0  Missed Shot                       Jump Shot  2PT Field Goal          Mid-Range  Right Side Center(RC)        16-24 ft.             20    108    173                    1               0
# 2   Shot Chart Detail  0021300002             70       2544  LeBron James  1610612748  Miami Heat       1                  4                  6    Made Shot                       Jump Shot  2PT Field Goal          Mid-Range           Left Side(L)        16-24 ft.             20   -198     45                    1               1
# 3   Shot Chart Detail  0021300002            124       2544  LeBron James  1610612748  Miami Heat       1                  0                  0  Missed Shot              Driving Layup Shot  2PT Field Goal    Restricted Area              Center(C)  Less Than 8 ft.              2     21      7                    1               0
# 4   Shot Chart Detail  0021300002            207       2544  LeBron James  1610612748  Miami Heat       2                  5                 16    Made Shot              Reverse Layup Shot  2PT Field Goal    Restricted Area              Center(C)  Less Than 8 ft.              2     15     17                    1               1
# 5   Shot Chart Detail  0021300002            222       2544  LeBron James  1610612748  Miami Heat       2                  4                 23    Made Shot  Driving Finger Roll Layup Shot  2PT Field Goal    Restricted Area              Center(C)  Less Than 8 ft.              0      1      3                    1               1
# 6   Shot Chart Detail  0021300002            340       2544  LeBron James  1610612748  Miami Heat       3                  7                 35  Missed Shot                       Jump Shot  2PT Field Goal          Mid-Range              Center(C)        16-24 ft.             17    -24    178                    1               0
# 7   Shot Chart Detail  0021300002            352       2544  LeBron James  1610612748  Miami Heat       3                  6                  3  Missed Shot                       Jump Shot  3PT Field Goal  Above the Break 3  Right Side Center(RC)          24+ ft.             26    159    206                    1               0
# 8   Shot Chart Detail  0021300002            426       2544  LeBron James  1610612748  Miami Heat       3                  0                 21  Missed Shot              Driving Layup Shot  2PT Field Goal    Restricted Area              Center(C)  Less Than 8 ft.              1     12      9                    1               0
# 9   Shot Chart Detail  0021300002            500       2544  LeBron James  1610612748  Miami Heat       4                  4                 31    Made Shot              Driving Layup Shot  2PT Field Goal    Restricted Area              Center(C)  Less Than 8 ft.              1     -8      7                    1               1
# 10  Shot Chart Detail  0021300002            558       2544  LeBron James  1610612748  Miami Heat       4                  1                  3    Made Shot                Pullup Jump shot  2PT Field Goal          Mid-Range  Right Side Center(RC)        16-24 ft.             17    105    138                    1               1
# 11  Shot Chart Detail  0021300005              6       2544  LeBron James  1610612748  Miami Heat       1                 11                  9  Missed Shot                       Jump Shot  2PT Field Goal          Mid-Range           Left Side(L)        16-24 ft.             16   -164     -2                    1               0
# 12  Shot Chart Detail  0021300005             38       2544  LeBron James  1610612748  Miami Heat       1                  7                  8    Made Shot              Fadeaway Bank shot  2PT Field Goal          Mid-Range           Left Side(L)         8-16 ft.              9    -92     14                    1               1
# 13  Shot Chart Detail  0021300005             49       2544  LeBron James  1610612748  Miami Heat       1                  6                 13    Made Shot              Reverse Layup Shot  2PT Field Goal    Restricted Area              Center(C)  Less Than 8 ft.              2     21     11                    1               1
# 14  Shot Chart Detail  0021300005             66       2544  LeBron James  1610612748  Miami Heat       1                  4                 14    Made Shot                       Jump Shot  3PT Field Goal      Left Corner 3           Left Side(L)          24+ ft.             22   -228     11                    1               1
# 15  Shot Chart Detail  0021300005            176       2544  LeBron James  1610612748  Miami Heat       2                  4                 57    Made Shot                      Layup Shot  2PT Field Goal    Restricted Area              Center(C)  Less Than 8 ft.              1     -5     15                    1               1
# 16  Shot Chart Detail  0021300005            189       2544  LeBron James  1610612748  Miami Heat       2                  2                 49    Made Shot              Driving Layup Shot  2PT Field Goal    Restricted Area              Center(C)  Less Than 8 ft.              1     -8     14                    1               1
# 17  Shot Chart Detail  0021300005            228       2544  LeBron James  1610612748  Miami Heat       3                 11                  5    Made Shot                       Jump Shot  3PT Field Goal  Above the Break 3  Right Side Center(RC)          24+ ft.             25    119    222                    1               1
# 18  Shot Chart Detail  0021300005            231       2544  LeBron James  1610612748  Miami Heat       3                 10                 19  Missed Shot                       Jump Shot  3PT Field Goal  Above the Break 3              Center(C)          24+ ft.             24    -18    242                    1               0
# 19  Shot Chart Detail  0021300005            242       2544  LeBron James  1610612748  Miami Heat       3                  9                  1    Made Shot                       Jump Shot  3PT Field Goal  Above the Break 3   Left Side Center(LC)          24+ ft.             25   -199    164                    1               1

# %% [markdown]
# * plot the player's shot data points in a figure

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

#-------------------------------
# Your code goes here.
# Add as many cells as you need
#-------------------------------

# asign Lebron.shotchart() to kobe_shots
Lebron_shots = Lebron.shotchart()

# set the color and size of the figure
sns.set_style("white")
sns.set_color_codes()
plt.figure(figsize=(12,11))

# plot scatterplot in the figure
plt.scatter(Lebron_shots.LOC_X, Lebron_shots.LOC_Y)
# show the figure
plt.show()

# %% [markdown]
# * plot the distribution of shots in the court in another figure using bar plot, heat map, etc.

# %%
#-------------------------------
# Your code goes here.
# Add as many cells as you need
#-------------------------------


from matplotlib.patches import Circle, Rectangle, Arc

def draw_court(ax=None, color='black', lw=2, outer_lines=False):
    # If an axes object isn't provided to plot onto, just get current one
    if ax is None:
        ax = plt.gca()

    # Create the various parts of an NBA basketball court

    # Create the basketball hoop
    # Diameter of a hoop is 18" so it has a radius of 9", which is a value
    # 7.5 in our coordinate system
    hoop = Circle((0, 0), radius=7.5, linewidth=lw, color=color, fill=False)

    # Create backboard
    backboard = Rectangle((-30, -7.5), 60, -1, linewidth=lw, color=color)

    # The paint
    # Create the outer box 0f the paint, width=16ft, height=19ft
    outer_box = Rectangle((-80, -47.5), 160, 190, linewidth=lw, color=color,
                          fill=False)
    # Create the inner box of the paint, widt=12ft, height=19ft
    inner_box = Rectangle((-60, -47.5), 120, 190, linewidth=lw, color=color,
                          fill=False)

    # Create free throw top arc
    top_free_throw = Arc((0, 142.5), 120, 120, theta1=0, theta2=180,
                         linewidth=lw, color=color, fill=False)
    # Create free throw bottom arc
    bottom_free_throw = Arc((0, 142.5), 120, 120, theta1=180, theta2=0,
                            linewidth=lw, color=color, linestyle='dashed')
    # Restricted Zone, it is an arc with 4ft radius from center of the hoop
    restricted = Arc((0, 0), 80, 80, theta1=0, theta2=180, linewidth=lw,
                     color=color)

    # Three point line
    # Create the side 3pt lines, they are 14ft long before they begin to arc
    corner_three_a = Rectangle((-220, -47.5), 0, 140, linewidth=lw,
                               color=color)
    corner_three_b = Rectangle((220, -47.5), 0, 140, linewidth=lw, color=color)
    # 3pt arc - center of arc will be the hoop, arc is 23'9" away from hoop
    # I just played around with the theta values until they lined up with the 
    # threes
    three_arc = Arc((0, 0), 475, 475, theta1=22, theta2=158, linewidth=lw,
                    color=color)

    # Center Court
    center_outer_arc = Arc((0, 422.5), 120, 120, theta1=180, theta2=0,
                           linewidth=lw, color=color)
    center_inner_arc = Arc((0, 422.5), 40, 40, theta1=180, theta2=0,
                           linewidth=lw, color=color)

    # List of the court elements to be plotted onto the axes
    court_elements = [hoop, backboard, outer_box, inner_box, top_free_throw,
                      bottom_free_throw, restricted, corner_three_a,
                      corner_three_b, three_arc, center_outer_arc,
                      center_inner_arc]

    if outer_lines:
        # Draw the half court line, baseline and side out bound lines
        outer_lines = Rectangle((-250, -47.5), 500, 470, linewidth=lw,
                                color=color, fill=False)
        court_elements.append(outer_lines)

    # Add the court elements onto the axes
    for element in court_elements:
        ax.add_patch(element)

    return ax

# %%
# set the size of figure, and the range of x and y
plt.figure(figsize=(12,11))
draw_court(outer_lines=True)
plt.xlim(-300,300)
plt.ylim(-100,500)
plt.show()

# %%
# add scatterplot in the court
plt.figure(figsize=(12,11))
plt.scatter(Lebron_shots.LOC_X, Lebron_shots.LOC_Y)
draw_court(outer_lines=True)
# Descending values along the axis from left to right
plt.xlim(300,-300)
plt.show()

# %%
from matplotlib.offsetbox import  OffsetImage
# create our jointplot

cmap=plt.cm.gist_heat_r
joint_shot_chart = sns.jointplot(Lebron_shots.LOC_X, Lebron_shots.LOC_Y, stat_func=None,
                                 kind='kde', space=0, color=cmap(.1), cmap=cmap, n_levels=50)

joint_shot_chart.fig.set_size_inches(12,11)

# A joint plot has 3 Axes, the first one called ax_joint 
# is the one we want to draw our court onto 
ax = joint_shot_chart.ax_joint
draw_court(ax)

# Adjust the axis limits and orientation of the plot in order
# to plot half court, with the hoop by the top of the plot
ax.set_xlim(-250,250)
ax.set_ylim(422.5, -47.5)

# Get rid of axis labels and tick marks
ax.set_xlabel('')
ax.set_ylabel('')
ax.tick_params(labelbottom='off', labelleft='off')

# Add a title
ax.set_title('FGA 2014-15 Reg. Season\n The Shooting Location Map of LeBron James', y=1.2, fontsize=14)

# Add Data Source and Author
ax.text(-250,445,'Data Source: stats.nba.com', fontsize=12)
plt.show()

# %% [markdown]
# # Problem 3: Game Moments (20 points)

# %% [markdown]
# * from the list in question 2, select one of the shots by the player, which you liked the most. Remember the GAME_ID and game_event_id of the shot.
# * use the the GAME_ID and game_event_id to show the animation of the moment of the game.

# %%
from IPython.display import IFrame
#-------------------------------
# Your code goes here.
# Add as many cells as you need
#-------------------------------

# Here is an example, please change it according to your game id and event id.
IFrame('http://stats.nba.com/movement/#!/?GameID=0021300005&GameEventID=176',
              width=700, height=400)
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="http://stats.nba.com/movement/#!/?GameID=0021300005&GameEventID=176"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# * Download the movement data of all the players in this game event.
# * load the data into a pandas data frame
# * create a  list containing the movement data for each player and the ball.

# %%
import requests

#-------------------------------
# Your code goes here.
# Add as many cells as you need
#-------------------------------
# Here is an example of the URL, please change it according to your game id and event id.
url = "http://stats.nba.com/stats/locations_getmoments/?eventid=176&gameid=0021300005"

# get data through url
response = requests.get(url)

# representing the JSON data 
response.json().keys()
# Out:
# [u'moments', u'visitor', u'gamedate', u'gameid', u'home']

# %%
# A dict containing home players data
home = response.json()["home"]
# A dict containig visiting players data
visitor = response.json()["visitor"]
# A list containing each moment
moments = response.json()["moments"]

# %%
# check the home
home
# Out:
# {u'abbreviation': u'PHI',
#  u'name': u'Philadelphia 76ers',
#  u'players': [{u'firstname': u'Kwame',
#    u'jersey': u'54',
#    u'lastname': u'Brown',
#    u'playerid': 2198,
#    u'position': u'C'},
#   {u'firstname': u'Thaddeus',
#    u'jersey': u'21',
#    u'lastname': u'Young',
#    u'playerid': 201152,
#    u'position': u'F'},
#   {u'firstname': u'Spencer',
#    u'jersey': u'00',
#    u'lastname': u'Hawes',
#    u'playerid': 201150,
#    u'position': u'C'},
#   {u'firstname': u'Evan',
#    u'jersey': u'12',
#    u'lastname': u'Turner',
#    u'playerid': 202323,
#    u'position': u'F-G'},
#   {u'firstname': u'Daniel',
#    u'jersey': u'33',
#    u'lastname': u'Orton',
#    u'playerid': 202350,
#    u'position': u'C'},
#   {u'firstname': u'James',
#    u'jersey': u'9',
#    u'lastname': u'Anderson',
#    u'playerid': 202341,
#    u'position': u'G-F'},
#   {u'firstname': u'Lavoy',
#    u'jersey': u'50',
#    u'lastname': u'Allen',
#    u'playerid': 202730,
#    u'position': u'F-C'},
#   {u'firstname': u'Darius',
#    u'jersey': u'7',
#    u'lastname': u'Morris',
#    u'playerid': 202721,
#    u'position': u'G'},
#   {u'firstname': u'Tony',
#    u'jersey': u'8',
#    u'lastname': u'Wroten',
#    u'playerid': 203100,
#    u'position': u'G'},
#   {u'firstname': u'Hollis',
#    u'jersey': u'31',
#    u'lastname': u'Thompson',
#    u'playerid': 203138,
#    u'position': u'G-F'},
#   {u'firstname': u'Michael',
#    u'jersey': u'1',
#    u'lastname': u'Carter-Williams',
#    u'playerid': 203487,
#    u'position': u'G'},
#   {u'firstname': u'Brandon',
#    u'jersey': u'20',
#    u'lastname': u'Davies',
#    u'playerid': 203561,
#    u'position': u'F'}],
#  u'teamid': 1610612755}

# %%
# check the visitor
visitor
# Out:
# {u'abbreviation': u'MIA',
#  u'name': u'Miami Heat',
#  u'players': [{u'firstname': u'Ray',
#    u'jersey': u'34',
#    u'lastname': u'Allen',
#    u'playerid': 951,
#    u'position': u'G'},
#   {u'firstname': u'Rashard',
#    u'jersey': u'9',
#    u'lastname': u'Lewis',
#    u'playerid': 1740,
#    u'position': u'F'},
#   {u'firstname': u'Shane',
#    u'jersey': u'31',
#    u'lastname': u'Battier',
#    u'playerid': 2203,
#    u'position': u'F'},
#   {u'firstname': u'LeBron',
#    u'jersey': u'6',
#    u'lastname': u'James',
#    u'playerid': 2544,
#    u'position': u'F'},
#   {u'firstname': u'Udonis',
#    u'jersey': u'40',
#    u'lastname': u'Haslem',
#    u'playerid': 2617,
#    u'position': u'F'},
#   {u'firstname': u'Chris',
#    u'jersey': u'1',
#    u'lastname': u'Bosh',
#    u'playerid': 2547,
#    u'position': u'C-F'},
#   {u'firstname': u'James',
#    u'jersey': u'22',
#    u'lastname': u'Jones',
#    u'playerid': 2592,
#    u'position': u'F-G'},
#   {u'firstname': u'Chris',
#    u'jersey': u'11',
#    u'lastname': u'Andersen',
#    u'playerid': 2365,
#    u'position': u'F-C'},
#   {u'firstname': u'Roger',
#    u'jersey': u'21',
#    u'lastname': u'Mason Jr.',
#    u'playerid': 2427,
#    u'position': u'G'},
#   {u'firstname': u'Joel',
#    u'jersey': u'50',
#    u'lastname': u'Anthony',
#    u'playerid': 201202,
#    u'position': u'C'},
#   {u'firstname': u'Mario',
#    u'jersey': u'15',
#    u'lastname': u'Chalmers',
#    u'playerid': 201596,
#    u'position': u'G'},
#   {u'firstname': u'Michael',
#    u'jersey': u'8',
#    u'lastname': u'Beasley',
#    u'playerid': 201563,
#    u'position': u'F'},
#   {u'firstname': u'Norris',
#    u'jersey': u'30',
#    u'lastname': u'Cole',
#    u'playerid': 202708,
#    u'position': u'G'}],
#  u'teamid': 1610612748}

# %%
# check the moments
moments[0]
# Out:
# [2,
#  1383177334035,
#  282.01,
#  11.0,
#  None,
#  [[-1, -1, 29.36415, 20.72952, 3.22871],
#   [1610612755, 201152, 25.19263, 30.54058, 0.0],
#   [1610612755, 201150, 2.17701, 11.26515, 0.0],
#   [1610612755, 202341, 15.65566, 47.84096, 0.0],
#   [1610612755, 203100, 29.3637, 19.12757, 0.0],
#   [1610612755, 203487, 16.64496, 2.53888, 0.0],
#   [1610612748, 2203, 24.23806, 19.50131, 0.0],
#   [1610612748, 2547, 5.07788, 18.27425, 0.0],
#   [1610612748, 2544, 21.87372, 27.89341, 0.0],
#   [1610612748, 201596, 11.58532, 35.63582, 0.0],
#   [1610612748, 202708, 15.04297, 11.65346, 0.0]]]

# %% [markdown]
# ** Load the data of moments into a pandas data frame **

# %%
# 1st create Column labels
headers = ["team_id", "player_id", "x_loc", "y_loc", 
           "radius", "moment", "game_clock", "shot_clock"]

# %%
# 2nd create the data of data frame, Initialize our new list, 
player_moments = []

for moment in moments:
    # For each player/ball in the list found within each moment
    for player in moment[5]:
        # Add additional information to each player/ball
        # This info includes the index of each moment, the game clock
        # and shot clock values for each moment
        player.extend((moments.index(moment), moment[2], moment[3]))
        player_moments.append(player)

# %%
# create a pandas data frame with data and column lables created before
df_moments = pd.DataFrame(player_moments, columns=headers)

# check the fist 11 rows of df_moments, the data of first moment
df_moments.head(11)
# Out:
#        team_id  player_id     x_loc     y_loc   radius  moment  game_clock  shot_clock
# 0           -1         -1  29.36415  20.72952  3.22871       0      282.01          11
# 1   1610612755     201152  25.19263  30.54058  0.00000       0      282.01          11
# 2   1610612755     201150   2.17701  11.26515  0.00000       0      282.01          11
# 3   1610612755     202341  15.65566  47.84096  0.00000       0      282.01          11
# 4   1610612755     203100  29.36370  19.12757  0.00000       0      282.01          11
# 5   1610612755     203487  16.64496   2.53888  0.00000       0      282.01          11
# 6   1610612748       2203  24.23806  19.50131  0.00000       0      282.01          11
# 7   1610612748       2547   5.07788  18.27425  0.00000       0      282.01          11
# 8   1610612748       2544  21.87372  27.89341  0.00000       0      282.01          11
# 9   1610612748     201596  11.58532  35.63582  0.00000       0      282.01          11
# 10  1610612748     202708  15.04297  11.65346  0.00000       0      282.01          11

# %% [markdown]
# ** Add columns that contain player names and jersey numbers **

# %%
# creates the players list with the home players
players = home["players"]
# Then add on the visiting players
players.extend(visitor["players"])

# check players
players[0:6]
# Out:
# [{u'firstname': u'Kwame',
#   u'jersey': u'54',
#   u'lastname': u'Brown',
#   u'playerid': 2198,
#   u'position': u'C'},
#  {u'firstname': u'Thaddeus',
#   u'jersey': u'21',
#   u'lastname': u'Young',
#   u'playerid': 201152,
#   u'position': u'F'},
#  {u'firstname': u'Spencer',
#   u'jersey': u'00',
#   u'lastname': u'Hawes',
#   u'playerid': 201150,
#   u'position': u'C'},
#  {u'firstname': u'Evan',
#   u'jersey': u'12',
#   u'lastname': u'Turner',
#   u'playerid': 202323,
#   u'position': u'F-G'},
#  {u'firstname': u'Daniel',
#   u'jersey': u'33',
#   u'lastname': u'Orton',
#   u'playerid': 202350,
#   u'position': u'C'},
#  {u'firstname': u'James',
#   u'jersey': u'9',
#   u'lastname': u'Anderson',
#   u'playerid': 202341,
#   u'position': u'G-F'}]

# %%
# create a dictionary with the player ID as the key and a list containing the player name and jersey number as the value
id_dict = {}

# Add the values we want
for player in players:
    id_dict[player['playerid']] = [player["firstname"]+" "+player["lastname"],
                                   player["jersey"]]

# %%
# check id_dict
id_dict
# Out:
# {951: [u'Ray Allen', u'34'],
#  1740: [u'Rashard Lewis', u'9'],
#  2198: [u'Kwame Brown', u'54'],
#  2203: [u'Shane Battier', u'31'],
#  2365: [u'Chris Andersen', u'11'],
#  2427: [u'Roger Mason Jr.', u'21'],
#  2544: [u'LeBron James', u'6'],
#  2547: [u'Chris Bosh', u'1'],
#  2592: [u'James Jones', u'22'],
#  2617: [u'Udonis Haslem', u'40'],
#  201150: [u'Spencer Hawes', u'00'],
#  201152: [u'Thaddeus Young', u'21'],
#  201202: [u'Joel Anthony', u'50'],
#  201563: [u'Michael Beasley', u'8'],
#  201596: [u'Mario Chalmers', u'15'],
#  202323: [u'Evan Turner', u'12'],
#  202341: [u'James Anderson', u'9'],
#  202350: [u'Daniel Orton', u'33'],
#  202708: [u'Norris Cole', u'30'],
#  202721: [u'Darius Morris', u'7'],
#  202730: [u'Lavoy Allen', u'50'],
#  203100: [u'Tony Wroten', u'8'],
#  203138: [u'Hollis Thompson', u'31'],
#  203487: [u'Michael Carter-Williams', u'1'],
#  203561: [u'Brandon Davies', u'20']}

# %%
# update id_dict to include an id for the ball
import numpy as np

id_dict.update({-1: ['ball', np.nan]})

# %%
# add "player_name" and "player_jersey" into df_moments
df_moments["player_name"] = df_moments.player_id.map(lambda x: id_dict[x][0])  ## a good way to map player_id, x is player_id

df_moments["player_jersey"] = df_moments.player_id.map(lambda x: id_dict[x][1])

# %%
# check the df_moments
df_moments.head(11)
# Out:
#        team_id  player_id     x_loc     y_loc   radius  moment  game_clock  shot_clock              player_name player_jersey
# 0           -1         -1  29.36415  20.72952  3.22871       0      282.01          11                     ball           NaN
# 1   1610612755     201152  25.19263  30.54058  0.00000       0      282.01          11           Thaddeus Young            21
# 2   1610612755     201150   2.17701  11.26515  0.00000       0      282.01          11            Spencer Hawes            00
# 3   1610612755     202341  15.65566  47.84096  0.00000       0      282.01          11           James Anderson             9
# 4   1610612755     203100  29.36370  19.12757  0.00000       0      282.01          11              Tony Wroten             8
# 5   1610612755     203487  16.64496   2.53888  0.00000       0      282.01          11  Michael Carter-Williams             1
# 6   1610612748       2203  24.23806  19.50131  0.00000       0      282.01          11            Shane Battier            31
# 7   1610612748       2547   5.07788  18.27425  0.00000       0      282.01          11               Chris Bosh             1
# 8   1610612748       2544  21.87372  27.89341  0.00000       0      282.01          11             LeBron James             6
# 9   1610612748     201596  11.58532  35.63582  0.00000       0      282.01          11           Mario Chalmers            15
# 10  1610612748     202708  15.04297  11.65346  0.00000       0      282.01          11              Norris Cole            30

# %% [markdown]
# * Plotting the Movements: plot the player's movements throughout the event in a figure.

# %%
#-------------------------------
# Your code goes here.
# Add as many cells as you need
#-------------------------------
# get Lebron' movements
Lebron_moments = df_moments[df_moments.player_name=="LeBron James"]
# read in the court png file
court = plt.imread("fullcourt.png")

#check Lebron_moments
Lebron_moments.head()
# Out:
#        team_id  player_id     x_loc     y_loc  radius  moment  game_clock  shot_clock   player_name player_jersey
# 8   1610612748       2544  21.87372  27.89341       0       0      282.01          11  LeBron James             6
# 19  1610612748       2544  21.84244  27.99501       0       1      281.97          11  LeBron James             6
# 30  1610612748       2544  21.78026  28.16302       0       2      281.93          11  LeBron James             6
# 41  1610612748       2544  21.76922  28.28939       0       3      281.89          11  LeBron James             6
# 52  1610612748       2544  21.75500  28.35131       0       4      281.85          11  LeBron James             6

# %% [markdown]
# ** plot the moments **

# %%
plt.figure(figsize=(15, 11.5))

# Plot the movemnts as scatter plot
# using a colormap to show change in game clock
plt.scatter(Lebron_moments.x_loc, Lebron_moments.y_loc, c=Lebron_moments.game_clock,
            cmap=plt.cm.Blues, s=1000, zorder=1)
# Darker colors represent moments earlier on in the game
cbar = plt.colorbar(orientation="horizontal")
cbar.ax.invert_xaxis()

# This plots the court
# zorder=0 sets the court lines underneath Harden's movements
# extent sets the x and y axis values to plot the image within.
# The original animation plots in the SVG coordinate space
# which has x=0, and y=0 at the top left.
# So, we set the axis values the same way in this plot.
# In the list we pass to extent 0,94 representing the x-axis 
# values and 50,0 representing the y-axis values
plt.imshow(court, zorder=0, extent=[0,94,50,0])

# extend the x-values beyond the court b/c Harden
# goes out of bounds
plt.xlim(0,101)


plt.show()

# %% [markdown]
# * Compute some basic statistics of the players: distance traveled, average running speed, average distances from other players

# %%
#-------------------------------
# Your code goes here.
# Add as many cells as you need
#-------------------------------

def travel_dist(player_locations):
    # get the differences for each column
    diff = np.diff(player_locations, axis=0)
    # square the differences and add them,
    # then get the square root of that sum
    dist = np.sqrt((diff ** 2).sum(axis=1))
    # Then return the sum of all the distances
    return dist.sum()

# %%
# Lebron's travel distance
dist = travel_dist(Lebron_moments[["x_loc", "y_loc"]])

dist
# Out:
# 213.42613124588505

# %%
# get the total distance traveled by each player
player_travel_dist = df_moments.groupby('player_name')[['x_loc', 'y_loc']].apply(travel_dist)
player_travel_dist
# Out:
# player_name
# Chris Bosh                 131.165241
# James Anderson             202.703860
# LeBron James               213.426131
# Mario Chalmers             173.909976
# Michael Carter-Williams    179.031772
# Norris Cole                171.505116
# Shane Battier              181.386527
# Spencer Hawes              212.401394
# Thaddeus Young             205.470862
# Tony Wroten                237.216838
# ball                       332.650172
# dtype: float64

# %% [markdown]
# ** calculating average speed **

# %%
# get the number of seconds for the play
seconds = df_moments.game_clock.max() - df_moments.game_clock.min()
# feet per second
Lebron_fps = dist / seconds
# convert to miles per hour
Lebron_mph = 0.681818 * Lebron_fps
Lebron_mph
# Out:
# 5.6054614003777727

# %%
# get the average speed for each player
player_speeds = (player_travel_dist/seconds) * 0.681818
player_speeds
# Out:
# player_name
# Chris Bosh                 3.444947
# James Anderson             5.323850
# LeBron James               5.605461
# Mario Chalmers             4.567602
# Michael Carter-Williams    4.702122
# Norris Cole                4.504440
# Shane Battier              4.763968
# Spencer Hawes              5.578548
# Thaddeus Young             5.396523
# Tony Wroten                6.230305
# ball                       8.736783
# dtype: float64

# %% [markdown]
# ** calculating the distance between players **

# %%
Lebron_loc = df_moments[df_moments.player_name=="LeBron James"][["x_loc", "y_loc"]]

# check the Lebron_loc
Lebron_loc.head()
# Out:
#        x_loc     y_loc
# 8   21.87372  27.89341
# 19  21.84244  27.99501
# 30  21.78026  28.16302
# 41  21.76922  28.28939
# 52  21.75500  28.35131

# %%
# get the locations for each player and the ball by player_name
group = df_moments[df_moments.player_name!="LeBron James"].groupby("player_name")[["x_loc", "y_loc"]]

# %%
from scipy.spatial.distance import euclidean

# Function to find the distance between players
# at each moment
def player_dist(player_a, player_b):
    return [euclidean(player_a.iloc[i], player_b.iloc[i])
            for i in range(len(player_a))]

# %%
# calculating the distance between LeBron James and other players, by applying the player_dist(player_a, Lebron_loc)
Lebron_dist = group.apply(player_dist, player_b=(Lebron_loc))

# %%
# check the Lebron_dist
Lebron_dist
# Out:
# player_name
# Chris Bosh                 [19.3553217594, 19.3951315089, 19.4465204247, ...
# James Anderson             [20.8942341608, 20.7426977769, 20.5296309866, ...
# Mario Chalmers             [12.8761829425, 12.8209225985, 12.7075690127, ...
# Michael Carter-Williams    [25.888069118, 25.892359692, 25.9657288459, 26...
# Norris Cole                [17.6180339869, 17.6866775448, 17.7977361917, ...
# Shane Battier              [8.718798429, 8.69493040865, 8.74916977744, 8....
# Spencer Hawes              [25.7771103006, 25.7787329577, 25.8008964573, ...
# Thaddeus Young             [4.24531183743, 4.47043720144, 4.66272639429, ...
# Tony Wroten                [11.5299501866, 11.3557680116, 11.3516511617, ...
# ball                       [10.3647412663, 10.1103382548, 10.1335129834, ...
# dtype: object

# %% [markdown]
# * Take a close look at the exact second when the player scored, plot a figure to show the distance between the player and the ball in that second
# * draw a vertical line in the figure, indicating the approximate moment of the ball arrive/leave the player's hand.

# %%
#-------------------------------
# Your code goes here.
# Add as many cells as you need
#-------------------------------

# Boolean mask used to grab the data within the proper time period
time_mask = (df_moments.game_clock <= 271) & (df_moments.game_clock >= 267) & \
            (df_moments.shot_clock <= 18.0) & (df_moments.shot_clock >= 14.0)
time_df = df_moments[time_mask]

# %% [markdown]
# From the animation it looks like LeBron James passes the ball around 15.3 to 15.4 seconds left in the quarter. We can check out the distance between him and the ball to be sure.

# %%
ball = time_df[time_df.player_name=="ball"]
Lebron2 = time_df[time_df.player_name=="LeBron James"]
Lebron_ball_dist = player_dist(ball[["x_loc", "y_loc"]],
                               Lebron2[["x_loc", "y_loc"]])

# %%
# plot a figure showing the distance between LeBron James and the ball
plt.figure(figsize=(12,9))

x = time_df.shot_clock.unique()
y =  Lebron_ball_dist
plt.plot(x, y)
plt.xlim(16, 15)

plt.xlabel("Shot Clock")
plt.ylabel("Distance between James and the Ball (feet)")
plt.vlines(15.4, 0, 30, color='gray', lw=0.7)

plt.show()

# %% [markdown]
# * Compute some statistics of the game moment and use these results to plot a figure and tell a story about why/how the player/team successfully scored in that moment.

# %% [markdown]
# Let's take another look at the moments animation. And go over what occurs during James' drive.

# %%
IFrame('http://stats.nba.com/movement/#!/?GameID=0021300005&GameEventID=176',
              width=700, height=400)
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="http://stats.nba.com/movement/#!/?GameID=0021300005&GameEventID=176"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# As LeBron James(blue 6) drives to the hoop, blue 1, 21, 00 and 9 come to defense James, leaving all the other red players open. Then James passes the ball to red 15 player, and the 15 player takes the shot as blue 8 tries to rush over to defend.
#
# In order to quantitate the process, we decide to calculate the distance between LeBron James and all the blue players, also the distance between red 15 and blue 8.

# %%
#-------------------------------
# Your code goes here.
# Add as many cells as you need
#-------------------------------

# we can get the distance between LeBron James and the other red players from player_dist


# Boolean mask to get the players we want
player_mask = (time_df.player_name=="Thaddeus Young") | \
              (time_df.player_name=="Spencer Hawes") | \
              (time_df.player_name=="Michael Carter-Williams") | \
              (time_df.player_name=="James Anderson") | \
              (time_df.player_name=="Tony Wroten") | \
              (time_df.player_name=="LeBron James") | \
              (time_df.player_name=="Mario Chalmers") 
# check the player_mask
player_mask.head()
# Out:
# 3036    False
# 3037     True
# 3038     True
# 3039     True
# 3040     True
# Name: player_name, dtype: bool

# %%
# Group by players and get their locations
group2 = time_df[player_mask].groupby('player_name')[["x_loc", "y_loc"]]

# %%
# Get the differences in distances that we want
LeBron_Thaddeus = player_dist(group2.get_group("LeBron James"),
                            group2.get_group("Thaddeus Young"))
LeBron_Spencer = player_dist(group2.get_group("LeBron James"),
                            group2.get_group("Spencer Hawes"))
LeBron_Michael = player_dist(group2.get_group("LeBron James"),
                            group2.get_group("Michael Carter-Williams"))
LeBron_James = player_dist(group2.get_group("LeBron James"),
                            group2.get_group("James Anderson"))
LeBron_Tony = player_dist(group2.get_group("LeBron James"),
                            group2.get_group("Tony Wroten"))
Mario_Tony = player_dist(group2.get_group("Mario Chalmers"),
                            group2.get_group("Tony Wroten"))

# %%
# Create some lists that will help create our plot
# Distance data
distances = [LeBron_Thaddeus, LeBron_Spencer, LeBron_Michael, LeBron_James, LeBron_Tony, Mario_Tony]
# Labels for each line that we will plopt
labels = ["Thaddeus - LeBron", "Spencer - LeBron", "Michael - LeBron", "James - LeBron", "Tony - LeBron", "Tony - Mario"]
# Colors for each line
colors = sns.color_palette('colorblind', 6)

plt.figure(figsize=(13,10))

# Use enumerate to index the labels and colors and match
# them with the proper distance data
for i, dist in enumerate(distances):
    plt.plot(time_df.shot_clock.unique(), dist, color=colors[i])
    
    y_pos = dist[-1]
    
    plt.text(13.975, y_pos, labels[i], fontsize=14, color=colors[i])

# Plot a line to indicate when Harden passes the ball
plt.vlines(15.4, 0, 30, color='gray', lw=0.7)
plt.annotate("LeBron passes the ball", (15.4, 26), 
             xytext=(16.5, 26), fontsize=14, 
             arrowprops=dict(facecolor='lightgray', shrink=0.10))

# Create horizontal grid lines
plt.grid(axis='y',color='gray', linestyle='--', lw=0.5, alpha=0.5)

plt.xlim(18, 14)

plt.title("The Distance (in feet) Between Players \nFrom the Beginning"
          " of LeBron James' Drive up until Mario Chalmers Releases his Shot", size=14)
plt.xlabel("Time Left on Shot Clock (seconds)", size=14)

# Get rid of unneeded chart lines
sns.despine(left=True, bottom=True) 

plt.show()

# %% [markdown]
# As is shown in the figure above, Michael is the one who defenses LeBron before LeBron's drive, and then LeBron drives to the hoop, Spencer, Thaddeus come to defense LeBron immediately, James doesn't move but stands near the hoop, Tony also doesn't move, keepping a distance with Mario. After LeBron passes the ball to Mario, Tony come to defense Mario, but it is too late. The reason why this shooting successes is partly from LeBron's good trick, attracting three players to defense him, and also partly from Tony's late to defense Mario. But actually, LeBron's drive leave two of his teammates open greatly, he can either pass the ball to Mario, or Norris.

# %% [markdown]
# *------------------------
#
# #Problem 4: Explore the data  (20 points)
#
# Run some additional experiments with the NBA data and the API.
# For example,
# * can you put together of a team of best players, based upon their statistical data.
# * Which team do you predict that will win the next NBA finals based upon the historical data of the players and the team.
# * Can you predict the NBA all-star team, based upon their performance data in the season?
#
# Define your own interesting question, collect the related data, compute the statistics, and visualize the results.

# %%
players_url = 'http://stats.nba.com/stats/leaguedashplayerstats?Coll'\
                'ege=&Conference=&Country=&DateFrom=&DateTo=&Divisio'\
                'n=&DraftPick=&DraftYear=&GameScope=&GameSegment=&Hei'\
                'ght=&LastNGames=0&LeagueID=00&Location=&MeasureType=B'\
                'ase&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceA'\
                'djust=N&PerMode=PerGame&Period=0&PlayerExperience=&Pla'\
                'yerPosition=&PlusMinus=N&Rank=N&Season=2014-15&SeasonS'\
                'egment=&SeasonType=Regular+Season&ShotClockRange=&Start'\
                'erBench=&TeamID=0&VsConference=&VsDivision=&Weight='
                
                
                
# Get the webpage containing the data
response = requests.get(players_url)

# Grab the headers to be used as column headers for our DataFrame
headers = response.json()['resultSets'][0]['headers']

# Grab the shot chart data
shots = response.json()['resultSets'][0]['rowSet']

# Create a DF using pandas
shot_df = pd.DataFrame(shots, columns=headers)

# View the head of the DataFrame and all its columns
from IPython.display import display
with pd.option_context('display.max_columns', None):
    display(shot_df.head(n=20))
# Out:
#     PLAYER_ID        PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  AGE  GP   W   L  W_PCT   MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB   REB  AST  TOV  STL  BLK  BLKA   PF  PFD   PTS  PLUS_MINUS  DD2  TD3  CFID           CFPARAMS
# 0      201985         A.J. Price  1610612756               PHX   28  26  11  15  0.423  12.4  2.0   5.3   0.372   0.6   2.2    0.263  0.6  0.9   0.667   0.2   1.0   1.2  1.8  0.5  0.3  0.0   0.2  0.6  1.2   5.1        -2.5    0    0     5  201985,1610612756
# 1      201166       Aaron Brooks  1610612741               CHI   30  82  50  32  0.610  23.0  4.2  10.0   0.421   1.5   3.8    0.387  1.8  2.1   0.833   0.4   1.6   2.0  3.2  1.9  0.7  0.2   0.6  2.3  1.8  11.6         2.6    1    0     5  201166,1610612741
# 2      203932       Aaron Gordon  1610612753               ORL   19  47  14  33  0.298  17.0  2.0   4.4   0.447   0.3   1.0    0.271  0.9  1.3   0.721   1.0   2.6   3.6  0.7  0.8  0.4  0.5   0.3  1.8  1.1   5.2        -3.5    1    0     5  203932,1610612753
# 3      203940      Adreian Payne  1610612750               MIN   24  32   7  25  0.219  23.1  2.8   6.9   0.414   0.0   0.3    0.111  0.9  1.4   0.652   1.5   3.6   5.1  0.9  1.4  0.6  0.3   0.3  2.8  1.3   6.7        -7.7    3    0     5  203940,1610612750
# 16     101161       Amir Johnson  1610612761               TOR   28  75  44  31  0.587  26.4  4.0   6.9   0.574   0.3   0.6    0.413  1.1  1.7   0.612   2.1   4.0   6.1  1.6  1.5  0.6  0.8   0.7  3.0  1.7   9.3         0.8    6    0     5  101161,1610612761
# 17       2760   Anderson Varejao  1610612739               CLE   32  26  16  10  0.615  24.4  4.3   7.7   0.555   0.0   0.1    0.000  1.3  1.7   0.733   2.2   4.3   6.5  1.3  1.3  0.7  0.6   0.6  2.2  1.8   9.8         0.2    2    0     5    2760,1610612739
# 18     203958      Andre Dawkins  1610612748               MIA   23   4   2   2  0.500   5.4  0.3   1.5   0.167   0.3   1.5    0.167  0.0  0.0   0.000   0.0   0.5   0.5  0.3  0.3  0.0  0.0   0.0  0.8  0.0   0.8        -1.0    0    0     5  203958,1610612748
# 19     203083     Andre Drummond  1610612765               DET   21  82  32  50  0.390  30.5  6.0  11.7   0.514   0.0   0.0    0.000  1.7  4.5   0.389   5.3   8.1  13.5  0.7  1.5  0.9  1.9   0.7  3.5  3.3  13.8        -0.7   48    0     5  203083,1610612765

# %%
# %matplotlib inline
import nbastats.nbastats as nbastats
import requests
import goldsberry
import pandas as pd
teams_url = 'http://stats.nba.com/stats/leaguegamelog?Counter=1000&Direction=DESC&LeagueID=00&'\
'PlayerOrTeam=T&Season=2014-15&SeasonType=Regular+Season&Sorter=PTS'
                
                
# Get the webpage containing the data
response = requests.get(teams_url)

# Grab the headers to be used as column headers for our DataFrame
headers = response.json()['resultSets'][0]['headers']

# Grab the shot chart data
data = response.json()['resultSets'][0]['rowSet']

# Create a DF using pandas
data_df = pd.DataFrame(data, columns=headers)

# View the head of the DataFrame and all its columns
from IPython.display import display
with pd.option_context('display.max_columns', None):
    display(data_df.head(n=200))
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME     GAME_ID      MATCHUP WL  MIN  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  VIDEO_AVAILABLE
# 0       22014  1610612742               DAL        Dallas Mavericks  0021401184    DAL @ DEN  W  290   57  109   0.523    11    29    0.379   19   24   0.792    11    38   49   39    8    6   17  23  144           1                1
# 1       22014  1610612743               DEN          Denver Nuggets  0021401184  DEN vs. DAL  L  289   53  125   0.424    15    43    0.349   22   25   0.880    27    34   61   29   10    1   15  26  143          -1                1
# 2       22014  1610612742               DAL        Dallas Mavericks  0021400180  DAL vs. LAL  W  241   51   82   0.622    18    35    0.514   20   28   0.714    11    28   39   37    4    2    9  16  140          34                1
# 3       22014  1610612740               NOP    New Orleans Pelicans  0021400128  NOP vs. MIN  W  240   56   84   0.667    15    20    0.750   12   16   0.750     3    31   34   31   13    3   13  30  139          48                1
# 4       22014  1610612760               OKC   Oklahoma City Thunder  0021401222    OKC @ MIN  W  241   52   95   0.547    12    28    0.429   22   31   0.710    18    28   46   22   10    6   13  25  138          25                1
# 5       22014  1610612760               OKC   Oklahoma City Thunder  0021400480  OKC vs. PHX  W  266   41   99   0.414    11    35    0.314   44   49   0.898    19    31   50   22    6    4   12  27  137           3                1
# 6       22014  1610612744               GSW   Golden State Warriors  0021400145    GSW @ LAL  W  240   46   86   0.535    14    28    0.500   30   34   0.882    11    40   51   32    4    5   16  26  136          21                1
# 198     22014  1610612749               MIL         Milwaukee Bucks  0021400156  MIL vs. NYK  W  240   43   78   0.551     9    17    0.529   22   27   0.815    17    27   44   30    5    0   16  24  117           4                1
# 199     22014  1610612750               MIN  Minnesota Timberwolves  0021400137    MIN @ DAL  L  241   43   86   0.500     7    17    0.412   24   29   0.828    12    29   41   24    2    2   17  30  117         -14                1
#
# [200 rows x 28 columns]

# %%
import numpy as np

#Map the original team data from stats to compute winning and losing stats of each team
def split_data(data):
    teams = {};
    count = 0;
    for r in data:
        count = count +1
        # Split and Strip whitspaces
        if ('@' in r[5]):
            s = r[5].split('@');
            [teamA,teamB] = [s[0].strip(), s[1].strip()]
        else:
            s = r[5].split('vs.');
            [teamA,teamB] = [s[0].strip(), s[1].strip()]
        result = r[26] / r[25]; #Calculate the extent of the "win" of "lose"
        if (teams.has_key(teamA)):
            tmp1 = teams[teamA]
            if (tmp1.has_key(teamB)):
                tmp2 = tmp1[teamB]
                if (result > 0):
                    tmp2['W'] += [result]
                else:
                    tmp2['L'] += [result]
            else:
                tmp2 = tmp1[teamB] = {'W' : [] , 'L' : []};
                if (result > 0):
                    tmp2['W'] += [result]
                else:
                    tmp2['L'] += [result]
        else:
            teams[teamA] = {};
            tmp2 = teams[teamA][teamB] = {'W' : [], 'L' : []};
            if (result > 0):
                tmp2['W'] += [result]
            else:
                tmp2['L'] += [result]
    # This is just to verify the total number of records
    print count
    return teams
d = split_data(data)

#Creating Stats Dictionary in the map: Compute the mean, std and Winning_Pct
def getstats(datalist):
    for key in datalist.keys():
        if len(datalist[key]) > 0:
            s = str(key) + " Stats"
            datalist[s] = (np.average(datalist[key]),np.std(datalist[key]))
    datalist['Winning_Pct'] = len(datalist['W']) * 1.0 / (len(datalist['W']) + len(datalist['L']))
def winning_perc(data):
    for teamA in data.keys():
        for teamB in data[teamA].keys():
            getstats(data[teamA][teamB])
winning_perc(d)
# Out:
# 2460

# %%
# Data Processing
# Forming the Team-to-Team Win_Matrix;
# Ai,j represents how many times Team i has beaten Team j
# Also calculate the total wins and losses per team
# The transpose of the Win_Matrix is the Loss_Matrix
def to_matrix(inputmap):
    wmatrix = []
    kwin = []
    klose = []
    count = 0
    for team in inputmap.keys():
        a = [len(inputmap[team][x]['W']) for x in inputmap[team].keys()]
        b = [len(inputmap[team][x]['L']) for x in inputmap[team].keys()]
        a = a[0:count] +[0] + a[count:]
        b = b[0:count] +[0] + b[count:]
        wmatrix += [a]
        kwin.append(sum(a))
        klose.append(sum(b))
        count = count +1
    return (pd.DataFrame(kwin,index = inputmap.keys(), columns = ['W']),
            pd.DataFrame(klose,index = inputmap.keys(), columns = ['L']),
            pd.DataFrame(wmatrix, index = inputmap.keys(), columns = inputmap.keys()))
(w,l,matrix) = to_matrix(d)

# %%
# The Win_Matrix of all 30 teams in season 2015
matrix
# Out:
#      MIL  GSW  MIN  TOR  ATL  BOS  DET  NYK  DEN  DAL  BKN  POR  ORL  MIA  CLE  SAS  CHA  UTA  CHI  HOU  WAS  LAL  PHI  MEM  LAC  SAC  OKC  PHX  IND  NOP
# MIL    0    0    2    4    1    2    3    4    1    0    3    1    2    1    1    0    1    0    1    0    1    1    4    1    1    2    1    1    2    0
# SAC    0    0    3    0    0    1    0    2    2    0    0    1    0    0    1    1    2    1    1    0    1    3    1    1    1    0    1    3    2    1
# OKC    1    1    4    1    1    2    1    1    3    1    0    1    2    1    1    2    2    1    0    2    3    2    1    1    3    2    0    3    1    1
# PHX    1    1    3    1    0    1    1    2    2    1    2    1    1    0    1    1    1    2    1    1    2    4    2    0    0    3    1    0    2    1
# IND    2    1    1    3    0    1    2    4    0    0    1    0    3    0    2    0    3    2    2    0    2    1    3    0    0    2    1    0    0    2
# NOP    2    1    4    2    1    0    2    1    1    1    2    0    3    2    0    3    1    2    1    2    0    4    1    2    1    3    1    2    0    0

# %%
# Network Analysis. ScoreRank the teams!
# The parameter alpha must be lower than the inverse of the maximum eigenvalues of Win_Matrix
maxalpha = 1.0 / max(np.linalg.eigvals(pd.DataFrame.as_matrix(matrix)))
print maxalpha
# set alpha to 0.8 times maxalpha
alpha = 0.027 * 0.8
part1 = (np.identity(30) - alpha * pd.DataFrame.as_matrix(matrix))
w_score = np.dot(np.matrix(part1).getI(),pd.DataFrame.as_matrix(w))
part1 = (np.identity(30) - alpha * np.transpose(pd.DataFrame.as_matrix(matrix)))
l_score = np.dot(np.matrix(part1).getI(),pd.DataFrame.as_matrix(l))
final_score = pd.DataFrame(w_score - l_score, index = d.keys(),columns = ['Score'])
#Plot the final scores for each team in an descending order.Their positions in the table are the final ranks.
final_score.sort('Score',ascending=False)
# Out:
# (0.0268849885472+0j)
#           Score
# GSW  278.787870
# ATL  198.711288
# LAC  159.851933
# HOU  154.521644
# MEM  153.632074
# SAS  152.399890
# CLE  136.187161
# POR  103.585822
# CHI   82.954698
# DAL   65.683515
# WAS   51.007446
# NOP   44.491778
# TOR   43.824231
# MIA   -0.055230
# OKC   -4.865887
# MIL   -5.687421
# UTA   -9.372791
# PHX  -14.143868
# BOS  -16.805062
# BKN  -39.151648
# IND  -41.550778
# SAC  -63.732720
# CHA  -80.421446
# DET  -96.771318
# ORL  -98.983076
# DEN -117.990781
# LAL -183.310652
# PHI -247.786274
# MIN -254.090847
# NYK -258.266797

# %% [markdown]
# # Bonus Question in Presentation Slides (10 points)

# %% [markdown]
# * Watch the movie Moneyball. While watching, take brief notes on how data science made a difference to the characters in the movie. After the movie is over, brainstorm as a group, other areas of life where data science could make a difference. Speculate on the arguments opponents of data science might make to using data science. Pick one for further consideration. As a group, create a 4 slide presentation that introduces the area of life you picked; how data science would make a difference; what the counter-arguments are; and whether or not your group thinks, in the end, it would be a good idea to introduce data science into that area of life.

# %% [markdown]
# *-----------------
# # Done
#
# All set!
#
# ** What do you need to submit?**
#
# * **Notebook File**: Save this IPython notebook, and find the notebook file in your folder (for example, "filename.ipynb"). This is the file you need to submit. Please make sure all the plotted tables and figures are in the notebook.
#
#
# * **PPT Slides**: please prepare PPT slides (for 10 minutes' talk) to present about the case study . We will ask two teams which are randomly selected to present their case studies in class for this case study.
#
# * ** Report**: please prepare a report (less than 10 pages) to report what you found in the data.
#     * What data you collected?
#     * Why this player/team/problem is interesting or important to you? (Motivations)
#     * How did you analyse the data?
#     * What did you find in the data?
#
#      (please include figures or tables in the report, but no source code)
#
# Please compress all the files in a zipped file.

# %% [markdown]
# # Grading Criteria:
#
# ** Totoal Points: 100 **
#
#
# ---------------------------------------------------------------------------
# ** Notebook:  **
#     Points: 60
#
#
#     -----------------------------------
#     Qestion 1:
#     Points: 5
#     -----------------------------------
#
#
#     -----------------------------------
#     Qestion 2:
#     Points: 15
#     -----------------------------------
#
#
#     -----------------------------------
#     Qestion 3:
#     Points: 20
#     -----------------------------------
#
#     -----------------------------------
#     Problem 4:
#     Points: 20
#     -----------------------------------
#
#
# ---------------------------------------------------------------------------
# ** Report: communicate the results**
#     Points: 20
#
# (1) What data you collected?
#     Points: 5
#
# (2) Why this problem/player/team/game moment is interesting or important to you? (Motivations)
#     Points: 5
#
# (3) How did you analyse the data?
#     Points: 5
#
# (4) What did you find in the data?
# (please include figures or tables in the report, but no source code)
#     Points: 5
#
#
#
# ---------------------------------------------------------------------------
# ** Slides (for 10 minutes of presentation): Story-telling **
#     Points: 20
#
#
# 1. Motivation about the data collection, why the problem/player/team/game moment is interesting to you.
#     Points: 5
#
# 2. Communicating Results (figure/table)
#     Points: 10
#
# 3. Story telling (How all the parts (data, analysis, result) fit together as a story?)
#     Points: 5
